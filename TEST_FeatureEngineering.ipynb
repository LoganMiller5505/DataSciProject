# %%
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv('data//1_preprocessed//preprocessed_dataset_with_5_clusters.csv')

data['energy_acoustic_ratio']     = data['energy'] / (data['acousticness'] + 1e-6)
data['acoustic_calm']             = data['acousticness'] * (1 - data['energy'])
data['loudness_norm']             = (data['loudness'] - data['loudness'].min()) / (data['loudness'].max() - data['loudness'].min())
data['loudness_x_acousticness']   = data['loudness_norm'] * data['acousticness']
data['loudness_x_energy']         = data['loudness_norm'] * data['energy']
data['dance_energy_ratio']        = data['danceability'] / (data['energy'] + 1e-6)
data['tempo_x_energy']            = (data['tempo'] / 250) * data['energy']
data['energy_x_danceability']     = data['energy'] * data['danceability']

data.to_csv('data//1_preprocessed//preprocessed_dataset_with_5_clusters_and_features.csv', index=False)

# %%
data = pd.read_csv('data//1_preprocessed//preprocessed_dataset_with_10_clusters.csv')

data['energy_acoustic_ratio']     = data['energy'] / (data['acousticness'] + 1e-6)
data['acoustic_calm']             = data['acousticness'] * (1 - data['energy'])
data['loudness_norm']             = (data['loudness'] - data['loudness'].min()) / (data['loudness'].max() - data['loudness'].min())
data['loudness_x_acousticness']   = data['loudness_norm'] * data['acousticness']
data['loudness_x_energy']         = data['loudness_norm'] * data['energy']
data['dance_energy_ratio']        = data['danceability'] / (data['energy'] + 1e-6)
data['tempo_x_energy']            = (data['tempo'] / 250) * data['energy']
data['energy_x_danceability']     = data['energy'] * data['danceability']

data.to_csv('data//1_preprocessed//preprocessed_dataset_with_10_clusters_and_features.csv', index=False)

# %%
data = pd.read_csv('data//1_preprocessed//preprocessed_dataset_with_15_clusters.csv')

data['energy_acoustic_ratio']     = data['energy'] / (data['acousticness'] + 1e-6)
data['acoustic_calm']             = data['acousticness'] * (1 - data['energy'])
data['loudness_norm']             = (data['loudness'] - data['loudness'].min()) / (data['loudness'].max() - data['loudness'].min())
data['loudness_x_acousticness']   = data['loudness_norm'] * data['acousticness']
data['loudness_x_energy']         = data['loudness_norm'] * data['energy']
data['dance_energy_ratio']        = data['danceability'] / (data['energy'] + 1e-6)
data['tempo_x_energy']            = (data['tempo'] / 250) * data['energy']
data['energy_x_danceability']     = data['energy'] * data['danceability']

data.to_csv('data//1_preprocessed//preprocessed_dataset_with_15_clusters_and_features.csv', index=False)

# %%
data = pd.read_csv('data//1_preprocessed//preprocessed_dataset_with_20_clusters.csv')

data['energy_acoustic_ratio']     = data['energy'] / (data['acousticness'] + 1e-6)
data['acoustic_calm']             = data['acousticness'] * (1 - data['energy'])
data['loudness_norm']             = (data['loudness'] - data['loudness'].min()) / (data['loudness'].max() - data['loudness'].min())
data['loudness_x_acousticness']   = data['loudness_norm'] * data['acousticness']
data['loudness_x_energy']         = data['loudness_norm'] * data['energy']
data['dance_energy_ratio']        = data['danceability'] / (data['energy'] + 1e-6)
data['tempo_x_energy']            = (data['tempo'] / 250) * data['energy']
data['energy_x_danceability']     = data['energy'] * data['danceability']

data.to_csv('data//1_preprocessed//preprocessed_dataset_with_20_clusters_and_features.csv', index=False)

# %%
data = pd.read_csv('data//1_preprocessed//preprocessed_dataset_with_25_clusters.csv')

data['energy_acoustic_ratio']     = data['energy'] / (data['acousticness'] + 1e-6)
data['acoustic_calm']             = data['acousticness'] * (1 - data['energy'])
data['loudness_norm']             = (data['loudness'] - data['loudness'].min()) / (data['loudness'].max() - data['loudness'].min())
data['loudness_x_acousticness']   = data['loudness_norm'] * data['acousticness']
data['loudness_x_energy']         = data['loudness_norm'] * data['energy']
data['dance_energy_ratio']        = data['danceability'] / (data['energy'] + 1e-6)
data['tempo_x_energy']            = (data['tempo'] / 250) * data['energy']
data['energy_x_danceability']     = data['energy'] * data['danceability']

data.to_csv('data//1_preprocessed//preprocessed_dataset_with_25_clusters_and_features.csv', index=False)

# %%
data = pd.read_csv('data//1_preprocessed//preprocessed_dataset_with_30_clusters.csv')

data['energy_acoustic_ratio']     = data['energy'] / (data['acousticness'] + 1e-6)
data['acoustic_calm']             = data['acousticness'] * (1 - data['energy'])
data['loudness_norm']             = (data['loudness'] - data['loudness'].min()) / (data['loudness'].max() - data['loudness'].min())
data['loudness_x_acousticness']   = data['loudness_norm'] * data['acousticness']
data['loudness_x_energy']         = data['loudness_norm'] * data['energy']
data['dance_energy_ratio']        = data['danceability'] / (data['energy'] + 1e-6)
data['tempo_x_energy']            = (data['tempo'] / 250) * data['energy']
data['energy_x_danceability']     = data['energy'] * data['danceability']

data.to_csv('data//1_preprocessed//preprocessed_dataset_with_30_clusters_and_features.csv', index=False)
